# %% [markdown]
# <a href="https://colab.research.google.com/github/rizqi89/crawing/blob/main/Temu_Kembali.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install re
# Out:
# ERROR: Could not find a version that satisfies the requirement re (from versions: none)
# ERROR: No matching distribution found for re

# %%
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/pilkada.csv')
df.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1837841535913869748  Sun Sep 22 13:09:02 +0000 2024             852
# 1  1838808215355822119  Wed Sep 25 05:10:16 +0000 2024             349
# 2  1838138710635991043  Mon Sep 23 08:49:54 +0000 2024            1822
# 3  1838141717435863212  Mon Sep 23 09:01:51 +0000 2024           13828
# 4  1838553047108325765  Tue Sep 24 12:16:19 +0000 2024             297
#
#                                            full_text               id_str  \
# 0  Siapa jagoanmu di pilkada 2024 gaes? Ini jagoa...  1837841535913869748
# 1  Alhamdulillah Pilkada Jakarta merdeka tanpa po...  1838808215355822119
# 2  Saat Ade Armando berusaha melakukan pembelaan ...  1838138710635991043
# 3  Beberapa hari ini banyak yang bertanya pada sa...  1838141717435863212
# 4  Tanpa Anies dan Kabib Baalawi pilkada DKI adem...  1838553047108325765
#
#                                            image_url in_reply_to_screen_name  \
# ...

# %%
df = df[['created_at', 'full_text', 'username']]
df
# Out:
#                          created_at  \
# 0    Sun Sep 22 13:09:02 +0000 2024
# 1    Wed Sep 25 05:10:16 +0000 2024
# 2    Mon Sep 23 08:49:54 +0000 2024
# 3    Mon Sep 23 09:01:51 +0000 2024
# 4    Tue Sep 24 12:16:19 +0000 2024
# ..                              ...
# 295  Tue Jun 26 10:44:43 +0000 2018
# 296  Wed Sep 25 11:25:53 +0000 2024
# 297  Wed Sep 25 09:16:21 +0000 2024
# 298  Thu Sep 26 03:20:00 +0000 2024
# 299  Tue Sep 24 23:58:14 +0000 2024
#
#                                              full_text         username
# 0    Siapa jagoanmu di pilkada 2024 gaes? Ini jagoa...         narkosun
# 1    Alhamdulillah Pilkada Jakarta merdeka tanpa po...  gustavssondhela
# 2    Saat Ade Armando berusaha melakukan pembelaan ...       BangPino__
# 3    Beberapa hari ini banyak yang bertanya pada sa...    aniesbaswedan
# 4    Tanpa Anies dan Kabib Baalawi pilkada DKI adem...        Kenikir27
# ..                                                 ...              ...
# ...

# %% [markdown]
# Cleaning

# %%
df.shape
# Out:
# (300, 3)

# %%
df = df.drop_duplicates(subset=['full_text'])

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# created_at    0
# full_text     0
# username      0
# dtype: int64

# %%
df.shape
# Out:
# (300, 3)

# %%
def clean_twiter_text(text):
  text = re.sub(r'@[A-Za-z0-9]+', '', text)
  text = re.sub(r'#\W+', '', text)
  text = re.sub(r'RT[\s]+', '', text)
  text = re.sub(r'https?://\S+', '', text)

  text = re.sub(r'[^A=Za=z0-9 ]', '', text)
  text = re.sub(r'\s+', '', text).strip()

  return text

  df['full_text'] = df['full_text'].apply(clean_twiter_text)

# %%
df['full_text'] = df['full_text'].str.lower()

# %%
df
# Out:
#                          created_at  \
# 0    Sun Sep 22 13:09:02 +0000 2024
# 1    Wed Sep 25 05:10:16 +0000 2024
# 2    Mon Sep 23 08:49:54 +0000 2024
# 3    Mon Sep 23 09:01:51 +0000 2024
# 4    Tue Sep 24 12:16:19 +0000 2024
# ..                              ...
# 295  Tue Jun 26 10:44:43 +0000 2018
# 296  Wed Sep 25 11:25:53 +0000 2024
# 297  Wed Sep 25 09:16:21 +0000 2024
# 298  Thu Sep 26 03:20:00 +0000 2024
# 299  Tue Sep 24 23:58:14 +0000 2024
#
#                                              full_text         username
# 0    siapa jagoanmu di pilkada 2024 gaes? ini jagoa...         narkosun
# 1    alhamdulillah pilkada jakarta merdeka tanpa po...  gustavssondhela
# 2    saat ade armando berusaha melakukan pembelaan ...       BangPino__
# 3    beberapa hari ini banyak yang bertanya pada sa...    aniesbaswedan
# 4    tanpa anies dan kabib baalawi pilkada dki adem...        Kenikir27
# ..                                                 ...              ...
# ...

# %% [markdown]
# Prosesing

# %%
#Normalisasi

norm = {" yg ": " yang ", " gak ": " tidak ", " vibes ": " suasana ", " mantap ": " keren "}

def normalisasi(str_text):
  for i in norm:
    str_text = str_text.replace(i, norm[i])
  return str_text

df['full_text'] = df['full_text'].apply(lambda x: normalisasi(x))
df
# Out:
#                          created_at  \
# 0    Sun Sep 22 13:09:02 +0000 2024
# 1    Wed Sep 25 05:10:16 +0000 2024
# 2    Mon Sep 23 08:49:54 +0000 2024
# 3    Mon Sep 23 09:01:51 +0000 2024
# 4    Tue Sep 24 12:16:19 +0000 2024
# ..                              ...
# 295  Tue Jun 26 10:44:43 +0000 2018
# 296  Wed Sep 25 11:25:53 +0000 2024
# 297  Wed Sep 25 09:16:21 +0000 2024
# 298  Thu Sep 26 03:20:00 +0000 2024
# 299  Tue Sep 24 23:58:14 +0000 2024
#
#                                              full_text         username
# 0    siapa jagoanmu di pilkada 2024 gaes? ini jagoa...         narkosun
# 1    alhamdulillah pilkada jakarta merdeka tanpa po...  gustavssondhela
# 2    saat ade armando berusaha melakukan pembelaan ...       BangPino__
# 3    beberapa hari ini banyak yang bertanya pada sa...    aniesbaswedan
# 4    tanpa anies dan kabib baalawi pilkada dki adem...        Kenikir27
# ..                                                 ...              ...
# ...

# %%
# !pip install Sastrawi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.4 MB/s eta 0:00:00
# ...

# %%
#Stopwords
import Sastrawi
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
more_stop_word = ["tidak"]

stop_words = StopWordRemoverFactory().get_stop_words()
stop_words.extend(more_stop_word)

new_array = ArrayDictionary(stop_words)
stop_words_remover = StopWordRemover(new_array)

def stopword(str_text):
  str_text = stop_words_remover.remove(str_text)
  return str_text

df['full_text'] = df['full_text'].apply(lambda x: normalisasi(x))
df.head
# Out:
# <bound method NDFrame.head of                          created_at  \
# 0    Sun Sep 22 13:09:02 +0000 2024
# 1    Wed Sep 25 05:10:16 +0000 2024
# 2    Mon Sep 23 08:49:54 +0000 2024
# 3    Mon Sep 23 09:01:51 +0000 2024
# 4    Tue Sep 24 12:16:19 +0000 2024
# ..                              ...
# 295  Tue Jun 26 10:44:43 +0000 2018
# 296  Wed Sep 25 11:25:53 +0000 2024
# 297  Wed Sep 25 09:16:21 +0000 2024
# 298  Thu Sep 26 03:20:00 +0000 2024
# 299  Tue Sep 24 23:58:14 +0000 2024
#
#                                              full_text         username
# 0    siapa jagoanmu di pilkada 2024 gaes? ini jagoa...         narkosun
# 1    alhamdulillah pilkada jakarta merdeka tanpa po...  gustavssondhela
# 2    saat ade armando berusaha melakukan pembelaan ...       BangPino__
# 3    beberapa hari ini banyak yang bertanya pada sa...    aniesbaswedan
# 4    tanpa anies dan kabib baalawi pilkada dki adem...        Kenikir27
# ...

# %%
#Tokenize
tokenize = df['full_text'].apply(lambda x:x.split())
tokenize
# Out:
# 0      [siapa, jagoanmu, di, pilkada, 2024, gaes?, in...
# 1      [alhamdulillah, pilkada, jakarta, merdeka, tan...
# 2      [saat, ade, armando, berusaha, melakukan, pemb...
# 3      [beberapa, hari, ini, banyak, yang, bertanya, ...
# 4      [tanpa, anies, dan, kabib, baalawi, pilkada, d...
#                              ...
# 295    [netralitas, tni, polri, dan, bin, dalam, pemi...
# 296    [bukti, nyata, elit, parpol, seenaknya, saja, ...
# 297    [hot, blora!, damn!, cara, cara, kotor, sudah,...
# 298    [relawan, dan, penduduk, tri, rismaharini, har...
# 299    [wah, ini, sebagai, tambahan, tenaga, untuk, m...
# Name: full_text, Length: 300, dtype: object
